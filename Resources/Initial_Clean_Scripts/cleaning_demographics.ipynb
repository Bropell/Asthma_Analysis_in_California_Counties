# %%
import pandas as pd

# %%
demo_data = pd.read_csv('DataSources/Census Data.csv')
demo_data.head()
# Out:
#       TractId    State          County  TotalPop   Men  Women  Hispanic  \
# 0  1001020100  Alabama  Autauga County      1845   899    946       2.4
# 1  1001020200  Alabama  Autauga County      2172  1167   1005       1.1
# 2  1001020300  Alabama  Autauga County      3385  1533   1852       8.0
# 3  1001020400  Alabama  Autauga County      4267  2001   2266       9.6
# 4  1001020500  Alabama  Autauga County      9965  5054   4911       0.9
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   86.3    5.2     0.0  ...   0.5          0.0         2.1         24.5
# 1   41.6   54.5     0.0  ...   0.0          0.5         0.0         22.2
# 2   61.4   26.5     0.6  ...   1.0          0.8         1.5         23.1
# 3   80.3    7.1     0.5  ...   1.5          2.9         2.1         25.9
# 4   77.5   16.4     0.0  ...   0.8          0.3         0.7         21.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
cali_data = demo_data.loc[demo_data['State'] == 'California']
cali_data
# Out:
#           TractId       State          County  TotalPop   Men  Women  \
# 3560   6001400100  California  Alameda County      2991  1442   1549
# 3561   6001400200  California  Alameda County      1997   992   1005
# 3562   6001400300  California  Alameda County      5123  2383   2740
# 3563   6001400400  California  Alameda County      3991  1810   2181
# 3564   6001400500  California  Alameda County      3944  1660   2284
# ...           ...         ...             ...       ...   ...    ...
# 11612  6115040800  California     Yuba County      4508  2380   2128
# 11613  6115040901  California     Yuba County      3080  1562   1518
# 11614  6115040902  California     Yuba County      1530   908    622
# 11615  6115041000  California     Yuba County      7365  3971   3394
# 11616  6115041100  California     Yuba County      4365  2358   2007
#
#        Hispanic  White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  \
# ...

# %%
cali_data.to_csv('DataSources/CLEAN_cali_demographics_data.csv', index=False)
