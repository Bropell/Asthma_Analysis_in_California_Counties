# %%
import pandas as pd

# %%
EV_regist_df = pd.read_excel('../Raw_Data/ca_ev_registrations_public.xlsx')

# %%
EV_regist_df.head()
# Out:
#              Vehicle ID County GEOID Registration Valid Date  DMV ID  \
# 0  CA-011-262244_x000D_        06059              2020-01-01      11
# 1  CA-011-262243_x000D_        06059              2020-01-01      11
# 2  CA-011-262246_x000D_        06059              2020-01-01      11
# 3  CA-011-262245_x000D_        06059              2020-01-01      11
# 4  CA-011-262242_x000D_        06059              2020-01-01      11
#
#                                 DMV Snapshot  Registration Expiration Date  \
# 0  CA Registration Data from CA (12/31/2020)                           NaN
# 1  CA Registration Data from CA (12/31/2020)                           NaN
# 2  CA Registration Data from CA (12/31/2020)                           NaN
# 3  CA Registration Data from CA (12/31/2020)                           NaN
# 4  CA Registration Data from CA (12/31/2020)                           NaN
#
#   State Abbreviation Geography       Vehicle Name         County
# ...

# %%
EVs_per_county = EV_regist_df.County.value_counts()
EVs_per_county = pd.DataFrame(EVs_per_county)

# %%
EVs_per_county.to_csv('DataSources/CLEAN_EVs_per_county.csv')
# Out:
#                         County
# Los Angeles County      154234
# Orange County            76706
# Santa Clara County       73092
# San Diego County         51616
# Alameda County           45785
# Contra Costa County      25938
# San Mateo County         24890
# Riverside County         22953
# San Bernardino County    17279
# San Francisco County     16134
# Sacramento County        15855
# Ventura County           13080
# Sonoma County             9868
# Marin County              9657
# Placer County             6339
# San Joaquin County        5918
# Fresno County             5481
# Santa Cruz County         5420
# Solano County             5139
# Santa Barbara County      5088
# Unknown                   4554
# San Luis Obispo County    3964
# Monterey County           3429
# Kern County               3222
# Yolo County               2948
# El Dorado County          2795
# Stanislaus County         2606
# Napa County               2365
# Humboldt County           1475
# ...
