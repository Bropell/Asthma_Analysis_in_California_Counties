# %%
import pandas as pd

# %%
fire_df = pd.read_csv('../Raw_Data/California_Fire_Incidents.csv')
fire_df.head()
# Out:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    AirTankers  ArchiveYear  CalFireIncident  \
# 0         NaN         2013             True
# 1         NaN         2013             True
# 2         NaN         2013             True
# 3         NaN         2013            False
# 4         NaN         2013             True
#
#                             CanonicalUrl  \
# 0         /incidents/2013/8/17/rim-fire/
# 1  /incidents/2013/5/30/powerhouse-fire/
# 2    /incidents/2013/7/15/mountain-fire/
# 3    /incidents/2013/8/10/american-fire/
# ...

# %%
fire_df = fire_df[['AcresBurned', 'ArchiveYear', 'CalFireIncident', 'Counties']]
fire_df
# Out:
#       AcresBurned  ArchiveYear  CalFireIncident     Counties
# 0        257314.0         2013             True     Tuolumne
# 1         30274.0         2013             True  Los Angeles
# 2         27531.0         2013             True    Riverside
# 3         27440.0         2013            False       Placer
# 4         24251.0         2013             True      Ventura
# ...           ...          ...              ...          ...
# 1631          9.0         2019             True    Riverside
# 1632          2.0         2019             True       Nevada
# 1633          NaN         2019            False         Yolo
# 1634          NaN         2019            False    San Diego
# 1635          NaN         2019            False    Riverside
#
# [1636 rows x 4 columns]

# %%
fire_df.dtypes
# Out:
# AcresBurned        float64
# ArchiveYear          int64
# CalFireIncident       bool
# Counties            object
# dtype: object

# %%
fire_df = fire_df.dropna()
fire_df
# Out:
#       AcresBurned  ArchiveYear  CalFireIncident     Counties
# 0        257314.0         2013             True     Tuolumne
# 1         30274.0         2013             True  Los Angeles
# 2         27531.0         2013             True    Riverside
# 3         27440.0         2013            False       Placer
# 4         24251.0         2013             True      Ventura
# ...           ...          ...              ...          ...
# 1628         10.0         2019             True        Butte
# 1629         10.0         2019             True     Siskiyou
# 1630         10.0         2019             True        Butte
# 1631          9.0         2019             True    Riverside
# 1632          2.0         2019             True       Nevada
#
# [1633 rows x 4 columns]

# %%
fire_df.to_csv('../Clean_Data/CLEAN_wildfire_data.csv', index=False)
