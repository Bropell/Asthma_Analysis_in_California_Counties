# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import db_password
import time

# %% [markdown]
# - This script imports the raw data from github
# - Organizes and cleans the dataframe
# - Exports the clean data to a csv
# - Imports the clean data directly to SQL

# %%
# import the file from github to a dataframe
url = 'https://raw.githubusercontent.com/Bropell/Asthma_Analysis_in_California_Counties/main/Resources/Raw_Data/Air_Pollutant_data.csv'
ap_df = pd.read_csv(url)
ap_df
# Out:
#        StateFIPS    State  CountyFIPS   County  Year  Value  Data Comment  \
# 0              1  Alabama        1001  Autauga  2005   0.72           NaN
# 1              1  Alabama        1001  Autauga  2005   2.60           NaN
# 2              1  Alabama        1001  Autauga  2005   2.87           NaN
# 3              1  Alabama        1001  Autauga  2005   0.61           NaN
# 4              1  Alabama        1001  Autauga  2005   0.03           NaN
# ...          ...      ...         ...      ...   ...    ...           ...
# 31415         56  Wyoming       56045   Weston  2011   0.20           NaN
# 31416         56  Wyoming       56045   Weston  2011   0.75           NaN
# 31417         56  Wyoming       56045   Weston  2011   1.14           NaN
# 31418         56  Wyoming       56045   Weston  2011   0.55           NaN
# 31419         56  Wyoming       56045   Weston  2011   0.01           NaN
#
#                              Pollutant
# 0                   Pollutant: Benzene
# 1              Pollutant: Formaldehyde
# 2              Pollutant: Acetaldehyde
# 3      Pollutant: Carbon tetrachloride
# 4             Pollutant: 1,3-butadiene
# ...                                ...
# 31415               Pollutant: Benzene
# 31416          Pollutant: Formaldehyde
# 31417          Pollutant: Acetaldehyde
# 31418  Pollutant: Carbon tetrachloride
# 31419         Pollutant: 1,3-butadiene
#
# [31420 rows x 8 columns]

# %%
# filter to just states with the name California
ap_df2 = ap_df.loc[ap_df.State == 'California']
ap_df2.head()
# Out:
#       StateFIPS       State  CountyFIPS   County  Year  Value  Data Comment  \
# 1850          6  California        6001  Alameda  2005   1.11           NaN
# 1851          6  California        6001  Alameda  2005   2.90           NaN
# 1852          6  California        6001  Alameda  2005   1.98           NaN
# 1853          6  California        6001  Alameda  2005   0.61           NaN
# 1854          6  California        6001  Alameda  2005   0.12           NaN
#
#                             Pollutant
# 1850               Pollutant: Benzene
# 1851          Pollutant: Formaldehyde
# 1852          Pollutant: Acetaldehyde
# 1853  Pollutant: Carbon tetrachloride
# 1854         Pollutant: 1,3-butadiene

# %%
# convert the year column to type string
ap_df2['Year'] = ap_df2['Year'].astype(str)
# Out:
# /Users/melphillips/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# select specific year of 2011
ap_df3 = ap_df2.loc[ap_df2.Year == '2011']
ap_df3.head()
# Out:
#       StateFIPS       State  CountyFIPS   County  Year  Value  Data Comment  \
# 1855          6  California        6001  Alameda  2011   0.66           NaN
# 1856          6  California        6001  Alameda  2011   1.33           NaN
# 1857          6  California        6001  Alameda  2011   1.20           NaN
# 1858          6  California        6001  Alameda  2011   0.55           NaN
# 1859          6  California        6001  Alameda  2011   0.07           NaN
#
#                             Pollutant
# 1855               Pollutant: Benzene
# 1856          Pollutant: Formaldehyde
# 1857          Pollutant: Acetaldehyde
# 1858  Pollutant: Carbon tetrachloride
# 1859         Pollutant: 1,3-butadiene

# %%
# reduce dataframe to just County Value Pollutant columns
ap_df4 = ap_df3[['County','Value','Pollutant']]
# ap_df4 = ap_df4.set_index("County")
ap_df4
# Out:
#        County  Value                        Pollutant
# 1855  Alameda   0.66               Pollutant: Benzene
# 1856  Alameda   1.33          Pollutant: Formaldehyde
# 1857  Alameda   1.20          Pollutant: Acetaldehyde
# 1858  Alameda   0.55  Pollutant: Carbon tetrachloride
# 1859  Alameda   0.07         Pollutant: 1,3-butadiene
# ...       ...    ...                              ...
# 2425     Yuba   0.45               Pollutant: Benzene
# 2426     Yuba   2.37          Pollutant: Formaldehyde
# 2427     Yuba   2.28          Pollutant: Acetaldehyde
# 2428     Yuba   0.55  Pollutant: Carbon tetrachloride
# 2429     Yuba   0.04         Pollutant: 1,3-butadiene
#
# [290 rows x 3 columns]

# %%
# Create pivot table for 'County', 'Value', 'Pollutant'
ap_df5 = ap_df4
ap_df5.reset_index().drop(columns='index', inplace=True)
pollutant_pivot = ap_df5.pivot(index='County', columns='Pollutant', values='Value')
pollutant_pivot = pollutant_pivot.reset_index()
pollutant_pivot
# Out:
# Pollutant           County  Pollutant: 1,3-butadiene  Pollutant: Acetaldehyde  \
# 0                  Alameda                      0.07                     1.20
# 1                   Alpine                      0.01                     0.99
# 2                   Amador                      0.02                     1.85
# 3                    Butte                      0.05                     2.28
# 4                Calaveras                      0.02                     1.76
# 5                   Colusa                      0.01                     1.85
# 6             Contra Costa                      0.06                     1.24
# 7                Del Norte                      0.01                     1.07
# 8                El Dorado                      0.03                     1.89
# 9                   Fresno                      0.04                     2.13
# 10                   Glenn                      0.02                     2.02
# 11                Humboldt                      0.03                     1.09
# 12                Imperial                      0.03                     2.22
# 13                    Inyo                      0.01                     1.06
# 14                    Kern                      0.03                     2.18
# 15                   Kings                      0.02                     1.98
# 16                    Lake                      0.02                     1.41
# 17                  Lassen                      0.01                     1.22
# 18             Los Angeles                      0.08                     1.87
# 19                  Madera                      0.02                     1.88
# 20                   Marin                      0.04                     1.07
# 21                Mariposa                      0.01                     1.77
# 22               Mendocino                      0.02                     1.31
# 23                  Merced                      0.03                     1.82
# 24                   Modoc                      0.01                     1.08
# 25                    Mono                      0.00                     0.78
# 26                Monterey                      0.03                     0.97
# 27                    Napa                      0.03                     1.32
# 28                  Nevada                      0.02                     2.03
# 29                  Orange                      0.07                     1.56
# 30                  Placer                      0.05                     2.08
# 31                  Plumas                      0.01                     1.47
# 32               Riverside                      0.03                     1.81
# 33              Sacramento                      0.09                     2.02
# 34              San Benito                      0.02                     1.13
# 35          San Bernardino                      0.03                     1.73
# 36               San Diego                      0.05                     1.50
# 37           San Francisco                      0.15                     1.40
# 38             San Joaquin                      0.05                     1.65
# 39         San Luis Obispo                      0.02                     1.13
# 40               San Mateo                      0.06                     0.96
# 41           Santa Barbara                      0.03                     1.19
# 42             Santa Clara                      0.06                     1.37
# 43              Santa Cruz                      0.04                     1.20
# 44                  Shasta                      0.03                     1.96
# 45                  Sierra                      0.01                     1.26
# 46                Siskiyou                      0.01                     1.19
# 47                  Solano                      0.04                     1.31
# 48                  Sonoma                      0.04                     1.34
# 49              Stanislaus                      0.04                     1.82
# 50                  Sutter                      0.06                     2.29
# 51                  Tehama                      0.02                     2.04
# 52                 Trinity                      0.01                     1.28
# 53                  Tulare                      0.03                     2.36
# 54                Tuolumne                      0.02                     1.78
# 55                 Ventura                      0.03                     1.43
# 56                    Yolo                      0.05                     1.82
# 57                    Yuba                      0.04                     2.28
#
# Pollutant  Pollutant: Benzene  Pollutant: Carbon tetrachloride  \
# 0                        0.66                             0.55
# 1                        0.07                             0.55
# 2                        0.22                             0.55
# 3                        0.48                             0.55
# 4                        0.21                             0.55
# 5                        0.25                             0.55
# 6                        0.58                             0.55
# 7                        0.29                             0.55
# 8                        0.30                             0.55
# 9                        0.47                             0.55
# 10                       0.38                             0.55
# 11                       0.37                             0.55
# 12                       0.73                             0.55
# 13                       0.20                             0.55
# 14                       0.43                             0.55
# 15                       0.39                             0.55
# 16                       0.29                             0.55
# 17                       0.14                             0.55
# 18                       0.76                             0.55
# 19                       0.41                             0.55
# 20                       0.45                             0.55
# 21                       0.13                             0.55
# 22                       0.35                             0.55
# 23                       0.50                             0.55
# 24                       0.20                             0.55
# 25                       0.07                             0.55
# 26                       0.41                             0.55
# 27                       0.40                             0.55
# 28                       0.25                             0.55
# 29                       0.69                             0.55
# 30                       0.51                             0.55
# 31                       0.12                             0.55
# 32                       0.42                             0.55
# 33                       0.80                             0.55
# 34                       0.41                             0.55
# 35                       0.48                             0.55
# 36                       0.82                             0.55
# 37                       1.51                             0.55
# 38                       0.60                             0.55
# 39                       0.29                             0.55
# 40                       0.53                             0.55
# 41                       0.37                             0.55
# 42                       0.67                             0.55
# 43                       0.44                             0.55
# 44                       0.38                             0.55
# 45                       0.12                             0.55
# 46                       0.19                             0.55
# 47                       0.48                             0.55
# 48                       0.46                             0.55
# 49                       0.55                             0.55
# 50                       0.58                             0.55
# 51                       0.30                             0.55
# 52                       0.10                             0.55
# 53                       0.45                             0.55
# 54                       0.23                             0.55
# 55                       0.41                             0.55
# 56                       0.59                             0.55
# 57                       0.45                             0.55
#
# Pollutant  Pollutant: Formaldehyde
# 0                             1.33
# 1                             0.76
# 2                             1.89
# 3                             2.34
# 4                             1.77
# 5                             1.72
# 6                             1.38
# 7                             0.89
# 8                             1.90
# 9                             2.20
# 10                            1.92
# 11                            0.92
# 12                            2.17
# 13                            0.82
# 14                            2.19
# 15                            1.90
# 16                            1.35
# 17                            0.95
# 18                            2.03
# 19                            1.92
# 20                            1.07
# 21                            1.60
# 22                            1.16
# 23                            1.89
# 24                            0.80
# 25                            0.55
# 26                            1.07
# 27                            1.31
# 28                            2.02
# 29                            1.74
# 30                            2.23
# 31                            1.20
# 32                            1.90
# 33                            2.33
# 34                            1.24
# 35                            1.77
# 36                            1.57
# 37                            1.69
# 38                            1.76
# 39                            1.22
# 40                            1.02
# 41                            1.36
# 42                            1.49
# 43                            1.25
# 44                            1.91
# 45                            1.01
# 46                            0.97
# 47                            1.37
# 48                            1.29
# 49                            1.92
# 50                            2.43
# 51                            1.92
# 52                            1.01
# 53                            2.39
# 54                            1.79
# 55                            1.55
# 56                            1.89
# 57                            2.37

# %%
# Check dtypes for columns 
pollutant_pivot.dtypes
# Out:
# Pollutant
# County                              object
# Pollutant: 1,3-butadiene           float64
# Pollutant: Acetaldehyde            float64
# Pollutant: Benzene                 float64
# Pollutant: Carbon tetrachloride    float64
# Pollutant: Formaldehyde            float64
# dtype: object

# %%
# Export the cleaned data to a csv file change to "DataSource to: ../Clean_Data/"
pollutant_pivot.to_csv('../Clean_Data/CLEAN_air_pollutant_data.csv', index=False)

# %%
# import the dataframe to a table in sql

# Make sure to add a config.py file in the folder where this script is that has the following
# db_password = "Your Password for SQL"
# also change the database name to the database we are importing the table to.
# You must create the database prior to running this script
# We use final_project for our database name
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/final_project"

engine = create_engine(db_string)

rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
#replace the file location to that of which the cleaned data was saved to csv.
#file line should match that of the export file location and name
for data in pd.read_csv(f'../Clean_Data/CLEAN_air_pollutant_data.csv', chunksize=1000000):
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    #name the table of which the dataframe is imported to in sql
    data.to_sql(name='air_pollutants', con=engine, index=False)
    rows_imported += len(data)

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 58...Done. 0.10276675224304199 total seconds elapsed
