# %%
#import dependencies
import pandas as pd
from sqlalchemy import create_engine
from config import db_password
import time

# %%
#import the file from github to a dataframe
url = 'https://raw.githubusercontent.com/Bropell/Asthma_Analysis_in_California_Counties/main/Resources/Raw_Data/Charging%20Stations.csv'
charging_df = pd.read_csv(url)
charging_df
# Out:
# /Users/melphillips/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (5,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Fuel Type Code                       Station Name  \
# 0               ELEC           LADWP - Truesdale Center
# 1               ELEC    LADWP - West LA District Office
# 2               ELEC      Los Angeles Convention Center
# 3               ELEC      LADWP - John Ferraro Building
# 4               ELEC         LADWP - Haynes Power Plant
# ...              ...                                ...
# 50284           ELEC                   VIP LOT STATION1
# 50285           ELEC          Prunedale Shopping Center
# 50286           ELEC          Beaverton Electric Avenue
# 50287           ELEC                      Shell - Inman
# 50288           ELEC  Westfield Trumbull (Trumbull, CT)
#
#                          Street Address          City State    ZIP  Plus4  \
# 0                    11797 Truesdale St    Sun Valley    CA  91352    NaN
# 1                 1394 S Sepulveda Blvd   Los Angeles    CA  90024    NaN
# 2                    1201 S Figueroa St   Los Angeles    CA  90015    NaN
# 3                         111 N Hope St   Los Angeles    CA  90012    NaN
# 4                         6801 E 2nd St    Long Beach    CA  90803    NaN
# ...                                 ...           ...   ...    ...    ...
# 50284          1501 Kirkwood Meadows Dr  Markleeville    CA  96120    NaN
# 50285         8065 San Miguel Canyon Rd       Salinas    CA  93907    NaN
# 50286  11665 SW Beaverton Hillsdale Hwy     Beaverton    OR  97005    NaN
# 50287                  2040 Highway 292         Inman    SC  29349    NaN
# 50288                  5065 Main Street      Trumbull    CT   6611    NaN
#
#       Station Phone Expected Date Groups With Access Code  ...  \
# 0               NaN           NaN                 Private  ...
# 1               NaN           NaN                 Private  ...
# 2      213-741-1151           NaN                  Public  ...
# 3               NaN           NaN                 Private  ...
# 4               NaN           NaN                 Private  ...
# ...             ...           ...                     ...  ...
# 50284  888-758-4389           NaN                  Public  ...
# 50285  877-455-3833           NaN                  Public  ...
# 50286  855-900-7584           NaN                  Public  ...
# 50287  855-900-7584           NaN                  Public  ...
# 50288  833-632-2778           NaN                  Public  ...
#
#       EV Pricing (French)  LPG Nozzle Types  Hydrogen Pressures  \
# 0                     NaN               NaN                 NaN
# 1                     NaN               NaN                 NaN
# 2                     NaN               NaN                 NaN
# 3                     NaN               NaN                 NaN
# 4                     NaN               NaN                 NaN
# ...                   ...               ...                 ...
# 50284                 NaN               NaN                 NaN
# 50285                 NaN               NaN                 NaN
# 50286                 NaN               NaN                 NaN
# 50287                 NaN               NaN                 NaN
# 50288                 NaN               NaN                 NaN
#
#        Hydrogen Standards  CNG Fill Type Code CNG PSI CNG Vehicle Class  \
# 0                     NaN                 NaN     NaN               NaN
# 1                     NaN                 NaN     NaN               NaN
# 2                     NaN                 NaN     NaN               NaN
# 3                     NaN                 NaN     NaN               NaN
# 4                     NaN                 NaN     NaN               NaN
# ...                   ...                 ...     ...               ...
# 50284                 NaN                 NaN     NaN               NaN
# 50285                 NaN                 NaN     NaN               NaN
# 50286                 NaN                 NaN     NaN               NaN
# 50287                 NaN                 NaN     NaN               NaN
# 50288                 NaN                 NaN     NaN               NaN
#
#       LNG Vehicle Class EV On-Site Renewable Source  Restricted Access
# 0                   NaN                         NaN                NaN
# 1                   NaN                         NaN                NaN
# 2                   NaN                         NaN                NaN
# 3                   NaN                         NaN                NaN
# 4                   NaN                         NaN                NaN
# ...                 ...                         ...                ...
# 50284               NaN                         NaN                NaN
# 50285               NaN                         NaN                NaN
# 50286               NaN                         NaN                NaN
# 50287               NaN                         NaN                NaN
# 50288               NaN                         NaN                NaN
#
# [50289 rows x 60 columns]

# %%
# Create a DF of the zipcodes for each County in California
zip_data = pd.read_csv('../Raw_Data/zip_code_database.csv')
zip_data = zip_data.loc[zip_data['state'] == 'CA']
zip_data = zip_data[['zip', 'county']]

# %%
# Rename column 
zip_data = zip_data.rename(columns={'zip':'ZIP'})

# %%
#reduce dataframe to just 'State', 'ZIP', 'Access Code', 'Latitude', 'Longitude' columns
charging_df = charging_df[['State', 'ZIP', 'Access Code', 'Latitude', 'Longitude']]

# %%
# Isolate CA chargers
charging_df = charging_df.loc[charging_df['State'] == 'CA']

# %%
# Merge zip dataframe and charging dataframe
charging_df2 = charging_df.merge(zip_data, on='ZIP',how='left')

# %%
# Create columns for counting public and private EV chargers
charging_df2['Total EV Chargers'] = 1
charging_df2
pub_priv = pd.get_dummies(charging_df2['Access Code'])
pub_priv
# Out:
#        private  public
# 0            1       0
# 1            1       0
# 2            0       1
# 3            1       0
# 4            1       0
# ...        ...     ...
# 14646        0       1
# 14647        0       1
# 14648        0       1
# 14649        0       1
# 14650        0       1
#
# [14651 rows x 2 columns]

# %%
# Add counts to charging DF
charging_df2['Private EV Chargers'] = pub_priv['private']
charging_df2['Public EV Chargers'] = pub_priv['public']
charging_df2
# Out:
#       State    ZIP Access Code   Latitude   Longitude        county  \
# 0        CA  91352     private  34.248319 -118.387971  Los Angeles
# 1        CA  90024     private  34.052542 -118.448504  Los Angeles
# 2        CA  90015      public  34.040539 -118.271387  Los Angeles
# 3        CA  90012     private  34.059133 -118.248589  Los Angeles
# 4        CA  90803     private  33.759802 -118.096665  Los Angeles
# ...     ...    ...         ...        ...         ...           ...
# 14646    CA  94555      public  37.540585 -122.077357      Alameda
# 14647    CA  94555      public  37.537684 -122.073972      Alameda
# 14648    CA  94555      public  37.537662 -122.073913      Alameda
# 14649    CA  96120      public  38.684660 -120.065169       Alpine
# 14650    CA  93907      public  36.801716 -121.664153     Monterey
#
#        Total EV Chargers  Private EV Chargers  Public EV Chargers
# 0                      1                    1                   0
# 1                      1                    1                   0
# 2                      1                    0                   1
# 3                      1                    1                   0
# 4                      1                    1                   0
# ...                  ...                  ...                 ...
# 14646                  1                    0                   1
# 14647                  1                    0                   1
# 14648                  1                    0                   1
# 14649                  1                    0                   1
# 14650                  1                    0                   1
#
# [14651 rows x 9 columns]

# %%
# Group by county and count total, private and public chargers, convert result to dataframe
private_chargers = pd.DataFrame(charging_df2.groupby('county')['Private EV Chargers'].sum()).reset_index()
public_chargers = pd.DataFrame(charging_df2.groupby('county')['Public EV Chargers'].sum()).reset_index()
all_chargers = pd.DataFrame(charging_df2.groupby('county')['Total EV Chargers'].sum()).reset_index()

# %%
glen_df = {'county': 'Glenn', 'Total EV Chargers':0,'Private EV Chargers':0,'Public EV Chargers':0}

# %%
# merge all counts into one dataframe
all_chargers = all_chargers.merge(private_chargers, on='county')
all_chargers = all_chargers.merge(public_chargers,on='county')
all_chargers
# Out:
#               county  Total EV Chargers  Private EV Chargers  \
# 0           Alameda                  78                   12
# 1            Alpine                   3                    0
# 2            Amador                   8                    0
# 3             Butte                  10                    2
# 4         Calaveras                   3                    0
# 5            Colusa                   1                    0
# 6      Contra Costa                  40                    9
# 7         Del Norte                   3                    0
# 8         El Dorado                  27                    0
# 9            Fresno                  91                   24
# 10         Humboldt                  20                    3
# 11         Imperial                   1                    0
# 12             Inyo                   4                    0
# 13             Kern                  36                    8
# 14            Kings                   9                    4
# 15             Lake                   3                    0
# 16           Lassen                   1                    0
# 17      Los Angeles                 721                  138
# 18           Madera                   9                    2
# 19            Marin                  21                    2
# 20         Mariposa                   5                    0
# 21        Mendocino                  35                    1
# 22           Merced                  10                    2
# 23            Modoc                   2                    0
# 24             Mono                   6                    0
# 25         Monterey                  37                    3
# 26             Napa                  78                    2
# 27           Nevada                  16                    0
# 28           Orange                 136                   23
# 29           Placer                  33                    6
# 30           Plumas                   3                    0
# 31        Riverside                 135                   10
# 32       Sacramento                  91                   21
# 33       San Benito                   3                    0
# 34   San Bernardino                  90                   21
# 35        San Diego                 193                   48
# 36    San Francisco                  59                   15
# 37      San Joaquin                  31                    7
# 38  San Luis Obispo                  87                    4
# 39        San Mateo                  53                    8
# 40    Santa Barbara                  52                    2
# 41      Santa Clara                 147                   25
# 42       Santa Cruz                  12                    0
# 43           Shasta                   9                    3
# 44           Sierra                   1                    0
# 45         Siskiyou                   6                    0
# 46           Solano                  43                    8
# 47           Sonoma                  64                    2
# 48       Stanislaus                  24                    6
# 49           Sutter                   1                    0
# 50           Tehama                   2                    0
# 51          Trinity                   3                    0
# 52           Tulare                   8                    3
# 53         Tuolumne                   9                    0
# 54          Ventura                  45                    6
# 55             Yolo                  47                    7
# 56             Yuba                   4                    3
#
#     Public EV Chargers
# 0                 66.0
# 1                  3.0
# 2                  8.0
# 3                  8.0
# 4                  3.0
# 5                  1.0
# 6                 31.0
# 7                  3.0
# 8                 27.0
# 9                 67.0
# 10                17.0
# 11                 1.0
# 12                 4.0
# 13                28.0
# 14                 5.0
# 15                 3.0
# 16                 1.0
# 17               583.0
# 18                 7.0
# 19                19.0
# 20                 5.0
# 21                34.0
# 22                 8.0
# 23                 2.0
# 24                 6.0
# 25                34.0
# 26                76.0
# 27                16.0
# 28               113.0
# 29                27.0
# 30                 3.0
# 31               125.0
# 32                70.0
# 33                 3.0
# 34                69.0
# 35               145.0
# 36                44.0
# 37                24.0
# 38                83.0
# 39                45.0
# 40                50.0
# 41               122.0
# 42                12.0
# 43                 6.0
# 44                 1.0
# 45                 6.0
# 46                35.0
# 47                62.0
# 48                18.0
# 49                 1.0
# 50                 2.0
# 51                 3.0
# 52                 5.0
# 53                 9.0
# 54                39.0
# 55                40.0
# 56                 1.0

# %%
all_chargers = all_chargers.append(glen_df, ignore_index=True)

# %%
#export the cleaned data to a csv file change to "DataSource to: ../Clean_Data/"
all_chargers.to_csv('../Clean_Data/CLEAN_EV_chargers.csv',index=False)

# %%
#import the dataframe to a table in sql

#Make sure to add a config.py file in the folder where this script is that has the following
#db_password = "Your Password for SQL"
#also change the database name to the database we are importing the table to.
#we use final_project for our database name and it is create prior to running this script
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/final_project"

engine = create_engine(db_string)

rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
#replace the file location to that of which the cleaned data was saved to csv.
#file line should match that of the export file location and name
for data in pd.read_csv(f'../Clean_Data/CLEAN_EV_chargers.csv', chunksize=1000000):
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    #name the table of which the dataframe is imported to in sql
    data.to_sql(name='ev_chargers', con=engine, index=False)
    rows_imported += len(data)

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 58...Done. 0.08643674850463867 total seconds elapsed
